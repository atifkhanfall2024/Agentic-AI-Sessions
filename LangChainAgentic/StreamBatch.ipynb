# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model='gemini-3-flash-preview')
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
response = model.invoke('Hi Do you know about ai')
print(response.text)
# Out:
# Yes, I do! In fact, **I am an AI** (a large language model trained by Google).
#
# Because I am an AI, I can explain how it works, its history, and how it’s being used today. Here is a quick overview of what AI is and the different ways we talk about it:
#
# ### 1. What is AI?
# At its simplest, Artificial Intelligence is the field of computer science dedicated to creating systems capable of performing tasks that usually require human intelligence. This includes things like:
# *   **Reasoning** (solving problems)
# *   **Learning** (improving from data)
# *   **Understanding language** (like this conversation)
# *   **Perception** (recognizing faces or objects in photos)
#
# ### 2. The Main Types of AI
# *   **Narrow AI (Weak AI):** This is what we have today. It is AI designed for a specific task—like Siri, Netflix recommendations, or self-driving car software.
# *   **Generative AI:** This is the category I belong to. We use "Neural Networks" to generate new content, such as text, images, music, or code.
# *   **General AI (AGI):** This is a theoretical version of AI that could do anything a human brain can do. We haven't reached this level yet.
#
# ### 3. How does it learn?
# Most modern AI uses **Machine Learning**. Instead of a human writing a million "if-then" rules, we give the computer massive amounts of data and let it find patterns itself.
# *   **Deep Learning:** A subset of machine learning that uses "Neural Networks" (inspired by the human brain) to process information in layers.
#
# ### 4. What can I help you with regarding AI?
# If you are curious about a specific part of AI, I can help you with:
# *   **History:** How did it start in the 1950s?
# *   **Ethics:** Is AI dangerous? What about bias or job loss?
# *   **Coding:** How do you build a simple AI?
# *   **Tools:** Which AI tools are best for writing, drawing, or productivity?
#
# **Is there a specific part of AI you’re curious about, or are you just getting started?**

# %%
for chunks in model.stream('Hi tell about about ai deeply'):
    print(chunks.text , end='|' , flush=True)
# Out:
# To understand Artificial Intelligence (AI) deeply, we have to look past the "magic" and| examine it as a blend of mathematics, computer science, and philosophy.
#
# Here is a deep dive into what AI is, how it functions|, and where it is going.
#
# ---
#
# ### 1. What is AI, Really?
# At its core,| AI is the field of computer science dedicated to creating systems capable of performing tasks that typically require human intelligence. This includes **pattern| recognition, decision-making, language translation, and visual perception.**
#
# Unlike traditional software, which follows a strict "if-then"| logic written by a human, AI learns to find its own rules by processing massive amounts of data.
#
# ---
#
# ### 2. The| Hierarchy: AI vs. ML vs. DL
# To understand AI deeply, you must understand its layers:
#
# *   **Artificial| Intelligence (The Umbrella):** Any technique that enables computers to mimic human behavior.
# *   **Machine Learning (ML|):** A subset of AI that uses **statistical methods** to enable machines to improve at tasks with experience. Instead of being| programmed how to identify a cat, the machine is shown 100,000 photos of cats until it learns the features| of one.
# *   **Deep Learning (DL):** A subset of ML based on **Artificial Neural Networks**. It mimics| the structure of the human brain (neurons and synapses) to process data in nonlinear ways. This is what powers modern wonders| like ChatGPT, self-driving cars, and facial recognition.
#
# ---
#
# ### 3. How AI "Learns"| (The Mechanics)
# AI learns through three primary paradigms:
#
# *   **Supervised Learning:** The AI is given| "labeled" data (e.g., a photo labeled "dog"). It learns to associate specific inputs with specific outputs.
# *   **|Unsupervised Learning:** The AI is given raw data with no labels. It must find hidden patterns or groupings on its own (e.|g., clustering customers by shopping habits).
# *   **Reinforcement Learning (RL):** The AI learns through trial| and error. It receives "rewards" for good actions and "penalties" for bad ones (how AI learns| to play chess or navigate a robot).
#
# ---
#
# ### 4. The Modern Breakthrough: Transformers and LLMs
# The current "|AI Boom" (starting around 2017) is driven by a specific architecture called the **Transformer**.
#
# Before| Transformers, AI read text one word at a time. Transformers introduced **"Self-Attention."** This allows the AI to look at an| entire paragraph at once and understand the relationship between words, no matter how far apart they are.
# *   *|Example:* In the sentence "The bank was closed because the river flooded," a Transformer knows "bank" refers to land|, not a financial institution, by looking at the word "river" simultaneously.
#
# **Large Language Models (LLMs|)** like GPT-4 are built on this. They don't "know" facts; they are essentially highly advanced "|next-token predictors" that have calculated the mathematical probability of which word should come next based on everything ever written on the internet.
#
# |---
#
# ### 5. Categorizing AI by Capability
# We generally divide AI into three stages of evolution:
#
# 1.  **|Artificial Narrow Intelligence (ANI):** Also called "Weak AI." It is designed for a specific task (e.g|., Siri, Google Search, AlphaGo). **We are currently in this stage.**
# 2.  **Artificial General Intelligence| (AGI):** "Strong AI." This would be an AI that can perform any intellectual task a human can do|. It can learn across domains, solve problems it wasn't trained for, and possess common sense. This does not exist| yet.
# 3.  **Artificial Super Intelligence (ASI):** A theoretical point where AI surpasses human intelligence across all fields,| including emotional intelligence and social skills.
#
# ---
#
# ### 6. The "Black Box" and Ethical Challenges
# One of the| deepest problems in AI is **Explainability**. In Deep Learning, the "brain" of the AI consists of billions of weights| (numbers) changing. Even the creators often cannot explain *exactly* why an AI made a specific decision. This leads| to several risks:
#
# *   **Bias:** If an AI is trained on data from a biased society, it will automate| that bias (e.g., biased hiring algorithms).
# *   **Hallucination:** LLMs can confidently state| things that are factually false because they are predicting words, not verifying facts.
# *   **Alignment:** How do we ensure that an| AI’s goals always remain aligned with human values? (If you tell an AI to "stop climate change," it might conclude| that removing humans is the most efficient way).
#
# ---
#
# ### 7. The Future: Agents and Multimodality
# The next| frontier of AI isn't just "chatting." It is:
# *   **Multimodality:** AI that can see|, hear, speak, and generate video simultaneously in real-time (like GPT-4o).
# *   **|AI Agents:** Moving from "chatbots" to "do-bots." These are systems that can use your browser,| book your flights, write code, and execute tasks autonomously.
# *   **Hardware Integration:** The rise of specialized AI chips (|like NVIDIA's GPUs) and "Humanoid Robotics" where AI gets a physical body.
#
# ### Summary
# Deep|ly speaking, AI is the transition from **Logic-based computing** (doing what we tell it) to **Prob|abilistic computing** (learning what to do). It is the most powerful tool humanity has ever built because it is a "|tool that builds other tools," accelerating science, medicine, and engineering at a rate impossible for the human brain alone.|||
